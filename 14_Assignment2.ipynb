# %% [markdown]
# 1) For diabetes.csv dataset, find the conditional probability that a person's Glucose levels are > 110 given that the person's BMI >= 25

# %%
# Marginal and Joint(Unconditional) probability
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("C:/Users/dbda.STUDENTSDC/Music/LabPractice/Notebooks/Datasets/diabetes.csv")

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
# Step 1: Select only relevant columns (Glucose & BMI)
df = df[['Glucose', 'BMI']]

# Step 2: Remove rows with missing values to ensure clean data
df.dropna(inplace=True)

# Step 3: Print dataset preview after cleaning
print("Preview of the cleaned dataset:")
print(df.head())
# Out:
# Preview of the cleaned dataset:
#    Glucose   BMI
# 0      148  33.6
# 1       85  26.6
# 2      183  23.3
# 3       89  28.1
# 4      137  43.1
# C:\Users\dbda.STUDENTSDC\AppData\Local\Temp\ipykernel_13652\1604259980.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace=True)

# %%
# Step 1: Count the total number of rows in the cleaned DataFrame
total = len(df)

# Step 2: Print the result for quick verification
print(f"Total rows after filtering and cleaning: {total}")
# Out:
# Total rows after filtering and cleaning: 768

# %%
# Step 1: Calculate the marginal probability of Glucose > 110
p_glucose = len(df[df['Glucose'] > 110]) / total  # Proportion of high Glucose levels

# Step 2: Calculate the marginal probability of BMI ≥ 25
p_bmi = len(df[df['BMI'] >= 25]) / total  # Proportion of BMI at or above 25

# Step 3: Print probabilities with proper formatting
print(f"P(Glucose > 110): {p_glucose:.3f}")  # Rounded to 3 decimal places
print(f"P(BMI >= 25): {p_bmi:.3f}")  # Rounded to 3 decimal places
# Out:
# P(Glucose > 110): 0.583
# P(BMI >= 25): 0.848

# %%
# Step 1: Calculate the joint probability of Glucose > 110 AND BMI ≥ 25
p_glucose_bmi = len(df[(df['Glucose'] > 110) & (df['BMI'] >= 25)]) / total

# Step 2: Print the result with proper formatting
print(f"P(Glucose > 110 and BMI ≥ 25): {p_glucose_bmi:.3f}")  # Rounded to 3 decimal places
# Out:
# P(Glucose > 110 and BMI ≥ 25): 0.523

# %%
# Step 1: Compute the conditional probability P(Glucose > 110 | BMI ≥ 25)
p_glucose_given_bmi = p_glucose_bmi / p_bmi

# Step 2: Print the result with proper formatting
print("\nConditional Probabilities:")
print(f"P(Glucose > 110 | BMI >= 25): {p_glucose_given_bmi:.3f}")  # Rounded to 3 decimal places
# Out:
# Conditional Probabilities:
# P(Glucose > 110 | BMI >= 25): 0.618

# %% [markdown]
# Q2. For the combined Marathon datasets ... Find the conditional probability of Finish within 3 hours given that pace < 8 minutes per mile
#
# Hint:
# Split the 'Official Time' column into hours, minutes, and seconds (split() function)
#
# Convert hours, minutes, and seconds columns to integers (See MSD example)
# Manually calculate total time in seconds
# Repeat for the 'Pace' column

# %%
df_2015 = pd.read_csv("C:/Users/dbda.STUDENTSDC/Music/LabPractice/Notebooks/Datasets/marathon_results_2015.csv")
df_2016 = pd.read_csv("C:/Users/dbda.STUDENTSDC/Music/LabPractice/Notebooks/Datasets/marathon_results_2016.csv")
df_2017 = pd.read_csv("C:/Users/dbda.STUDENTSDC/Music/LabPractice/Notebooks/Datasets/marathon_results_2017.csv")

# %%
# Concatenate the datasets into a single DataFrame

df = pd.concat([df_2015, df_2016, df_2017])
df
# Out:
#        Unnamed: 0    Bib                      Name  Age M/F          City  \
# 0             0.0      3            Desisa, Lelisa   25   M          Ambo
# 1             1.0      4     Tsegay, Yemane Adhane   30   M   Addis Ababa
# 2             2.0      8            Chebet, Wilson   29   M      Marakwet
# 3             3.0     11          Kipyego, Bernard   28   M       Eldoret
# 4             4.0     10             Korir, Wesley   32   M        Kitale
# ...           ...    ...                       ...  ...  ..           ...
# 26405     26405.0  25166  Steinbach, Paula Eyvonne   61   F       Ontario
# 26406     26406.0  25178        Avelino, Andrew R.   25   M  Fayetteville
# 26407     26407.0  27086           Hantel, Johanna   57   F       Malvern
# 26408     26408.0  25268              Reilly, Bill   64   M      New York
# 26409     26409.0  25266             Rigsby, Scott   48   M    Alpharetta
#
#       State Country Citizen Unnamed: 9  ...      30K      35K      40K  \
# ...

# %%
# Step 1: Split 'Official Time' into hours, minutes, and seconds
df[['of_Hours', 'of_Minutes', 'of_Seconds']] = df['Official Time'].str.split(':', expand=True)

# Step 2: Split 'Pace' into hours, minutes, and seconds
df[['pace_Hours', 'pace_Minutes', 'pace_Seconds']] = df['Pace'].str.split(':', expand=True)

# Step 3: Convert extracted values to numeric type for calculations
df[['of_Hours', 'of_Minutes', 'of_Seconds', 'pace_Hours', 'pace_Minutes', 'pace_Seconds']] = df[
    ['of_Hours', 'of_Minutes', 'of_Seconds', 'pace_Hours', 'pace_Minutes', 'pace_Seconds']
].astype(int)

# Step 4: Display the modified DataFrame
df.head()  # Shows a preview of the updated dataset
# Out:
#    Unnamed: 0 Bib                   Name  Age M/F         City State Country  \
# 0         0.0   3         Desisa, Lelisa   25   M         Ambo   NaN     ETH
# 1         1.0   4  Tsegay, Yemane Adhane   30   M  Addis Ababa   NaN     ETH
# 2         2.0   8         Chebet, Wilson   29   M     Marakwet   NaN     KEN
# 3         3.0  11       Kipyego, Bernard   28   M      Eldoret   NaN     KEN
# 4         4.0  10          Korir, Wesley   32   M       Kitale   NaN     KEN
#
#   Citizen Unnamed: 9  ... Overall Gender Division Unnamed: 8 of_Hours  \
# 0     NaN        NaN  ...       1      1        1        NaN        2
# 1     NaN        NaN  ...       2      2        2        NaN        2
# 2     NaN        NaN  ...       3      3        3        NaN        2
# 3     NaN        NaN  ...       4      4        4        NaN        2
# 4     NaN        NaN  ...       5      5        5        NaN        2
#
#   of_Minutes of_Seconds pace_Hours pace_Minutes pace_Seconds
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 79638 entries, 0 to 26409
# Data columns (total 32 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     53008 non-null  float64
#  1   Bib            79638 non-null  object
#  2   Name           79638 non-null  object
#  3   Age            79638 non-null  int64
#  4   M/F            79638 non-null  object
#  5   City           79637 non-null  object
#  6   State          70645 non-null  object
#  7   Country        79638 non-null  object
#  8   Citizen        3440 non-null   object
#  9   Unnamed: 9     158 non-null    object
#  10  5K             79638 non-null  object
#  11  10K            79638 non-null  object
#  12  15K            79638 non-null  object
#  13  20K            79638 non-null  object
#  14  Half           79638 non-null  object
#  15  25K            79638 non-null  object
#  16  30K            79638 non-null  object
# ...

# %%
df['of_Hours'] = pd.to_numeric(df['of_Hours'])
df['of_Minutes'] = pd.to_numeric(df['of_Minutes'])
df['of_Seconds'] = pd.to_numeric(df['of_Seconds'])
df['pace_Hours'] = pd.to_numeric(df['pace_Hours'])
df['pace_Minutes'] = pd.to_numeric(df['pace_Minutes'])
df['pace_Seconds'] = pd.to_numeric(df['pace_Seconds'])

# # Convert time-related columns to numeric for calculations
# time_cols = ['of_Hours', 'of_Minutes', 'of_Seconds', 'pace_Hours', 'pace_Minutes', 'pace_Seconds']
# df[time_cols] = df[time_cols].apply(pd.to_numeric)

# # Print a preview to verify successful conversion
# print(df.dtypes)  # Displays column data types

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 79638 entries, 0 to 26409
# Data columns (total 32 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     53008 non-null  float64
#  1   Bib            79638 non-null  object
#  2   Name           79638 non-null  object
#  3   Age            79638 non-null  int64
#  4   M/F            79638 non-null  object
#  5   City           79637 non-null  object
#  6   State          70645 non-null  object
#  7   Country        79638 non-null  object
#  8   Citizen        3440 non-null   object
#  9   Unnamed: 9     158 non-null    object
#  10  5K             79638 non-null  object
#  11  10K            79638 non-null  object
#  12  15K            79638 non-null  object
#  13  20K            79638 non-null  object
#  14  Half           79638 non-null  object
#  15  25K            79638 non-null  object
#  16  30K            79638 non-null  object
# ...

# %%
# Step 1: Convert 'Official Time' to total seconds
df["of_Total"] = df["of_Hours"] * 3600 + df["of_Minutes"] * 60 + df["of_Seconds"]

# Step 2: Convert 'Pace' to total seconds
df["pace_Total"] = df["pace_Hours"] * 3600 + df["pace_Minutes"] * 60 + df["pace_Seconds"]

# Step 3: Display a preview for verification
print(df[['of_Total', 'pace_Total']].head())  # Shows the first few rows
# Out:
#    of_Total  pace_Total
# 0      7757         296
# 1      7788         298
# 2      7822         299
# 3      7847         300
# 4      7849         300

# %%
df.head()
# Out:
#    Unnamed: 0 Bib                   Name  Age M/F         City State Country  \
# 0         0.0   3         Desisa, Lelisa   25   M         Ambo   NaN     ETH
# 1         1.0   4  Tsegay, Yemane Adhane   30   M  Addis Ababa   NaN     ETH
# 2         2.0   8         Chebet, Wilson   29   M     Marakwet   NaN     KEN
# 3         3.0  11       Kipyego, Bernard   28   M      Eldoret   NaN     KEN
# 4         4.0  10          Korir, Wesley   32   M       Kitale   NaN     KEN
#
#   Citizen Unnamed: 9  ... Division Unnamed: 8 of_Hours of_Minutes of_Seconds  \
# 0     NaN        NaN  ...        1        NaN        2          9         17
# 1     NaN        NaN  ...        2        NaN        2          9         48
# 2     NaN        NaN  ...        3        NaN        2         10         22
# 3     NaN        NaN  ...        4        NaN        2         10         47
# 4     NaN        NaN  ...        5        NaN        2         10         49
#
# ...

# %%
# Step 1: Select only the relevant columns for analysis
df = df[['of_Total', 'pace_Total']]

# Step 2: Remove rows with missing values to ensure clean data
df.dropna(inplace=True)

# Step 3: Display the cleaned dataset preview
print("Preview of the refined dataset:")
print(df.head())  # Shows the first few rows for quick inspection
# Out:
# Preview of the refined dataset:
#    of_Total  pace_Total
# 0      7757         296
# 1      7788         298
# 2      7822         299
# 3      7847         300
# 4      7849         300
# C:\Users\dbda.STUDENTSDC\AppData\Local\Temp\ipykernel_13652\1490989781.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace=True)

# %%
# Step 1: Count the total number of rows in the DataFrame
total = len(df)

# Step 2: Print the result for verification
print(f"Total rows in the DataFrame: {total}")
# Out:
# Total rows in the DataFrame: 79638

# %%
# Step 1: Compute the marginal probability of finishing within 3 hours
p_of_total = len(df[df['of_Total'] <= (3*60*60)]) / total  # Total seconds in 3 hours

# Step 2: Compute the marginal probability of pace being under 8 minutes/mile
p_pace_total = len(df[df['pace_Total'] < (8*60)]) / total  # Total seconds in 8 minutes

# Step 3: Print the results with proper formatting
print(f"P(of_Total ≤ 3 Hours): {p_of_total:.3f}")  # Rounded to 3 decimal places
print(f"P(pace_Total < 8 Minutes): {p_pace_total:.3f}")  # Rounded to 3 decimal places
# Out:
# P(of_Total ≤ 3 Hours): 0.070
# P(pace_Total < 8 Minutes): 0.305

# %%
# Step 1: Compute the joint probability of finishing within 3 hours AND pace under 8 minutes per mile
p_official_pace = len(df[(df['of_Total'] <= (3 * 60 * 60)) & (df['pace_Total'] < (8 * 60))]) / total

# Step 2: Print the result with proper formatting
print(f"P(of_Total ≤ 3 Hours and pace_Total < 8 Minutes): {p_official_pace:.3f}")
# Out:
# P(of_Total ≤ 3 Hours and pace_Total < 8 Minutes): 0.070

# %%
# Step 1: Compute the conditional probability P(of_Total ≤ 3 Hours | pace_Total < 8 Minutes)
p_total_given_pace = p_official_pace / p_pace_total  # Uses joint probability & marginal probability

# Step 2: Print the result with proper formatting
print("\nConditional Probabilities:")
print(f"P(of_Total ≤ 3 Hours | pace_Total < 8 Minutes): {p_total_given_pace:.3f}")  # Rounded to 3 decimal places
# Out:
# Conditional Probabilities:
# P(of_Total ≤ 3 Hours | pace_Total < 8 Minutes): 0.229

# %% [markdown]
# Q3). Find the conditional probability of winning a nobel prize in physics given the laureate is female.

# %%
df = pd.read_csv("C:/Users/dbda.STUDENTSDC/Music/LabPractice/Notebooks/Datasets/nobel.csv")

# %%
N = len(df)
print(f"Total rows in the DataFrame: {N}")
# Out:
# Total rows in the DataFrame: 950

# %%
df
# Out:
#      awardYear           category  \
# 0         2001  Economic Sciences
# 1         1975            Physics
# 2         2004          Chemistry
# 3         1982          Chemistry
# 4         1979            Physics
# ..         ...                ...
# 945       1972            Physics
# 946       1954          Chemistry
# 947       1911          Chemistry
# 948       1981              Peace
# 949       1963              Peace
#
#                                       categoryFullName  sortOrder portion  \
# 0    The Sveriges Riksbank Prize in Economic Scienc...          2  01-Mar
# 1                           The Nobel Prize in Physics          1  01-Mar
# 2                         The Nobel Prize in Chemistry          1  01-Mar
# 3                         The Nobel Prize in Chemistry          1       1
# 4                           The Nobel Prize in Physics          2  01-Mar
# ..                                                 ...        ...     ...
# ...

# %%
# Step 1: Remove rows where 'gender' column has missing values
df.dropna(subset=['gender'], inplace=True)

# Step 2: Display dataset preview to verify changes
print("Preview after dropping missing gender values:")
print(df.head())
# Out:
# Preview after dropping missing gender values:
#    awardYear           category  \
# 0       2001  Economic Sciences
# 1       1975            Physics
# 2       2004          Chemistry
# 3       1982          Chemistry
# 4       1979            Physics
#
#                                     categoryFullName  sortOrder portion  \
# 0  The Sveriges Riksbank Prize in Economic Scienc...          2  01-Mar
# 1                         The Nobel Prize in Physics          1  01-Mar
# 2                       The Nobel Prize in Chemistry          1  01-Mar
# 3                       The Nobel Prize in Chemistry          1       1
# 4                         The Nobel Prize in Physics          2  01-Mar
#
#    prizeAmount  prizeAmountAdjusted dateAwarded prizeStatus  \
# 0     10000000             12295082  10/10/2001    received
# 1       630000              3404179  17/10/1975    received
# 2     10000000             11762861  06/10/2004    received
# ...

# %%
# Step 1: Count the total number of rows in the DataFrame
N = len(df)

# Step 2: Print the result for verification
print(f"Total rows in the DataFrame: {N}")
# Out:
# Total rows in the DataFrame: 923

# %%
df.head()
# Out:
#    awardYear           category  \
# 0       2001  Economic Sciences
# 1       1975            Physics
# 2       2004          Chemistry
# 3       1982          Chemistry
# 4       1979            Physics
#
#                                     categoryFullName  sortOrder portion  \
# 0  The Sveriges Riksbank Prize in Economic Scienc...          2  01-Mar
# 1                         The Nobel Prize in Physics          1  01-Mar
# 2                       The Nobel Prize in Chemistry          1  01-Mar
# 3                       The Nobel Prize in Chemistry          1       1
# 4                         The Nobel Prize in Physics          2  01-Mar
#
#    prizeAmount  prizeAmountAdjusted dateAwarded prizeStatus  \
# 0     10000000             12295082  10/10/2001    received
# 1       630000              3404179  17/10/1975    received
# 2     10000000             11762861  06/10/2004    received
# 3      1150000              3102518  18/10/1982    received
# ...

# %%
# Step 1: Count the number of entries where 'category' is 'Physics'
A = len(df[df['category'] == 'Physics'])

# Step 2: Print the result for verification
print(f"Total entries in the 'Physics' category: {A}")
# Out:
# Total entries in the 'Physics' category: 213

# %%
print(df['gender'].unique())  # Shows distinct gender categories
# Out:
# ['male' 'female']

# %%
# Step 1: Count the number of entries where 'gender' is 'female'
B = len(df[df['gender'] == 'female'])

# Step 2: Print the result for verification
print(f"Total number of female entries: {B}")
# Out:
# Total number of female entries: 54

# %%
# Step 1: Count the number of entries where 'category' is 'Physics' AND 'gender' is 'female'
A_and_B = len(df[(df['category'] == 'Physics') & (df['gender'] == 'female')])

# Step 2: Print the result for verification
print(f"Total number of female entries in the 'Physics' category: {A_and_B}")
# Out:
# Total number of female entries in the 'Physics' category: 3

# %%
# Step 1: Calculate marginal probabilities
P_A = A / N  # Probability of category being 'Physics'
P_B = B / N  # Probability of gender being 'female'

# Step 2: Calculate conditional probability P(female | Physics)
P_B_given_A = A_and_B / A  # Probability of being female, given the category is 'Physics'

# Step 3: Print rounded values for readability
print(round(P_A, 2))  # Marginal probability of 'Physics'
print(round(P_B, 2))  # Marginal probability of 'female'
print(round(P_B_given_A, 2))  # Conditional probability P(female | Physics)
# Out:
# 0.23
# 0.06
# 0.01

# %%
# Step 1: Compute conditional probability P(Physics | Female) using Bayes' Theorem
P_A_given_B = (P_B_given_A * P_A) / P_B

# Step 2: Print the result for verification
print(f"P(Physics | Female): {round(P_A_given_B, 2)}")
# Out:
# P(Physics | Female): 0.06

# %%
# Step 1: Calculate P(A | B) = P(Physics | Female)
P_A_given_B = A_and_B / B  # Probability of 'Physics' given that gender is 'female'

# Step 2: Print rounded result
print(round(P_A_given_B, 2))
# Out:
# 0.06

# %% [markdown]
# Q3)2). Find the conditional probability of winning a nobel prize in Literature given the laureate was born in the USA

# %%
A = len(df[df['category'] == 'Literature'])

# %%
# Step 1: Count the number of entries where laureate was born in the USA
B = len(df[df['birth_country'] == 'USA'])

# Step 2: Print the result for verification
print(f"Total number of laureates born in the USA: {B}")

# Step 1: Count the number of entries where the category is 'Literature' AND laureate was born in the USA
A_and_B = len(df[(df['category'] == 'Literature') & (df['birth_country'] == 'USA')])

# Step 2: Print the result for verification
print(f"Total number of Literature laureates born in the USA: {A_and_B}")

# Step 1: Calculate marginal probabilities
P_A = A / N  # Probability of laureate winning in Literature
P_B = B / N  # Probability of laureate being born in the USA

# Step 2: Calculate conditional probability P(Literature | USA)
P_B_given_A = A_and_B / A  # Probability of laureate being born in USA, given they won in Literature

# Step 3: Print rounded values for readability
print(round(P_A, 2))  # Marginal probability of winning in Literature
print(round(P_B, 2))  # Marginal probability of laureate born in USA
print(round(P_B_given_A, 2))  # Conditional probability P(USA | Literature)

# Step 1: Compute conditional probability P(Literature | USA) using Bayes' Theorem
P_A_given_B = (P_B_given_A * P_A) / P_B

# Step 2: Print the result for verification
print(f"P(Literature | Born in USA): {round(P_A_given_B, 2)}")

# Step 1: Calculate P(A | B) = P(Literature | Born in USA)
P_A_given_B = A_and_B / B  # Probability of winning in Literature given laureate was born in the USA

# Step 2: Print rounded result
print(round(P_A_given_B, 2))
# Out:
# Total number of laureates born in the USA: 274
# Total number of Literature laureates born in the USA: 9
# 0.13
# 0.3
# 0.08
# P(Literature | Born in USA): 0.03
# 0.03
